// %% [markdown]
// ## 2025

// %%
let total_income_2025 = 443297.00;
let texable_income_2025 = 411797.00;
let effective_tax_rate_2025 = 0.1938;
let total_tax_2025 = 87980.00;
let total_tax_2025_type1 = total_income_2025 * effective_tax_rate_2025;
let total_tax_2025_type2 = texable_income_2025 * effective_tax_rate_2025;
println!("total tax 2025: {}", total_tax_2025);
println!("total tax 2025 by total_income: {}", total_tax_2025_type1);
println!("total tax 2025 by taxable_income: {}", total_tax_2025_type2);
// Out:
// total tax 2025: 87980
// total tax 2025 by total_income: 85910.9586
// total tax 2025 by taxable_income: 79806.2586

// %% [markdown]
// ## 2024

// %%
let total_income_2024 = 178586.00;
let texable_income_2024 = 149386.00;
let effective_tax_rate_2024 = 0.1286;
let total_tax_2024 = 22971.00;
let total_tax_2024_type1 = total_income_2024 * effective_tax_rate_2024;
let total_tax_2024_type2 = texable_income_2024 * effective_tax_rate_2024;
println!("total tax 2024: {}", total_tax_2024);
println!("total tax 2024 by total_income: {}", total_tax_2024_type1);
println!("total tax 2024 by taxable_income: {}", total_tax_2024_type2);
// Out:
// total tax 2024: 22971
// total tax 2024 by total_income: 22966.1596
// total tax 2024 by taxable_income: 19211.0396

// %%
443297 - 31500
// Out:
// 411797
